# %%
import pandas as pd
import torch
from torch.optim import AdamW
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from torch.utils.data import TensorDataset, DataLoader
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
import numpy as np
from torch.nn import BCEWithLogitsLoss

# %%
# Bước 1: Đọc và tiền xử lý dữ liệu
data_path = "facebook_comment_2k7.csv"
data = pd.read_csv(data_path)
data['label'] = data['label'].apply(lambda x: eval(x))

# %%
# Bước 2: Tokenization
tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base")
encoded_data = tokenizer.batch_encode_plus(
    data['text'].tolist(), 
    add_special_tokens=True, 
    return_attention_mask=True, 
    padding='max_length', 
    max_length=256, 
    truncation=True,
    return_tensors='pt'
)

# %%
# Bước 3: Chuẩn bị dữ liệu
mlb = MultiLabelBinarizer()
labels = mlb.fit_transform(data['label'])
labels_tensor = torch.tensor(labels, dtype=torch.float)

# Tạo TensorDataset và DataLoader
dataset = TensorDataset(encoded_data['input_ids'], encoded_data['attention_mask'], labels_tensor)

# Chia dữ liệu thành tập huấn luyện và kiểm thử
train_dataset, val_dataset = train_test_split(dataset, test_size=0.1)
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False)

# %%
train_loader

# %%
# Bước 4: Xây dựng mô hình
model = AutoModelForSequenceClassification.from_pretrained("vinai/phobert-base", num_labels=len(mlb.classes_))
model.to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at vinai/phobert-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# RobertaForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(64001, 768, padding_idx=1)
#       (position_embeddings): Embedding(258, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=5, bias=True)
#   )
# )

# %%
model = AutoModelForSequenceClassification.from_pretrained("vinai/phobert-base", num_labels=len(mlb.classes_))
model.load_state_dict(torch.load('model.pth'))
model.eval()
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at vinai/phobert-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# RobertaForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(64001, 768, padding_idx=1)
#       (position_embeddings): Embedding(258, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=5, bias=True)
#   )
# )

# %%
# Bước 5: Huấn luyện mô hình
optimizer = AdamW(model.parameters(), lr=2e-5)
loss_fn = BCEWithLogitsLoss()

epochs = 4

for epoch in range(epochs):
    model.train()
    total_loss = 0
    for batch in train_loader:
        batch = tuple(b.to(torch.device("cuda" if torch.cuda.is_available() else "cpu")) for b in batch)
        inputs, masks, labels = batch
        model.zero_grad()
        
        outputs = model(inputs, attention_mask=masks)
        loss = loss_fn(outputs.logits, labels)
        loss.backward()
        total_loss += loss.item()
        
        optimizer.step()
    print(f"Epoch {epoch+1}, Loss: {total_loss / len(train_loader)}")

# %%
torch.save(model.state_dict(), 'model.pth')

# %%
correct_predictions = 0
total_samples = 0

for i, batch in enumerate(val_loader):
    inputs, masks, labels = batch
    model.eval()
    with torch.no_grad():
        outputs = model(inputs, attention_mask=masks)
        predictions = torch.sigmoid(outputs.logits)
        # print(predictions)
        predicted_labels = (predictions > 0.3).int()
        predicted_labels = mlb.inverse_transform(predicted_labels)

    true_labels_list = mlb.inverse_transform(labels.int().cpu().numpy())

    for pred_labels, true_labels in zip(predicted_labels, true_labels_list):
        if set(pred_labels) == set(true_labels):
            correct_predictions += 1
        total_samples += 1

    for j in range(inputs.size(0)):  # Duyệt qua từng mẫu trong batch
        text = tokenizer.decode(inputs[j], skip_special_tokens=True)
        print("Sequence:", text)
        print("Predicted label:", predicted_labels[j])
        print("Hand-labeled:", mlb.inverse_transform(labels)[j])
# Out:
# Sequence: Dm~ đồ ranh con dám hun ng thg của ta huhu
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Chúng em đang còn sin tint Merzy có chất son và tone màu son tương tự, em gửi chị tham khảo qua nhé ạ
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Có con mắt j của sasuke có khả năng điều khiển á. Lấy cn mắt đó đem chịch gái khỏi chê :)
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Cần tiền vay được ngayNói không với phí trước VAY NHANH TRONG NGÀY CHỈ CẦN CMT+ATMmiễn phí lãi 10 ngày đầu tiênAi cần vay đăng ký tại đây https://shorten.asia/29GChqeN
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: Em sinh e be xong nguc phang chang co ji! E muon lam lang nguc,nhung nguc ben phai cua e co mot u xo nho bang hat dau,neu lam pho thuat co anh huong gi ko bs?,xin tu van gium e!
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Nguyễn Anh Tú im cái j cái lũ ngu gen ăn tức ở muôn đời nát. Đéo tìm hiểu suốt ngày đi cắn bừa tóm dc đá vào mõm.
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('harassment',)
# Sequence: Em mông to và tròn chắc đam mê gym lắm hả
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Phạm Thị Kiều Hoa m điên. Trên này ngắm không đụng được cũng không tiếc. Ngắm ở ngoài không đụng được tức ói máu luôn á
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Thương Thương thốt ra oy bị chửi cho ngu người@@
# Predicted label: ('harassment',)
# Hand-labeled: ('harassment',)
# Sequence: Y aparte de nosotros, algun club catalan ha dicho algo?? O estan a las ordenes de los d la cera d enfrente??
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Lưu Chí Công xàm. Đối với em như vậy là hoàn hảo dồi.
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: vay nhanh không cần thế chấp chỉ cần CMT, có số điện thoại https://shorten.asia/KBj8ecgt
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: Nguyễn Thị Thùy Linh đm m lấy ở cmt
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: ad cho em hỏi là khi nào có đợt xét tuyển lần 2 vậy ạ?
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: A chạy về a út cho phát vào mặt hay a chạy về để a bị út cho phát vào mặt
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: Thử tèo k có con cu to bự xem trang có chọn k.xạo lol riết r quen
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Tặng quà e đi.. e ăn cú lừa nhiều lắm rồi c ơi
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Si solo servian para darle las nalgas al Madrid, ahi en segunda estan mejor
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Nhỏ Lầy Đăng ký hồ sơ trực tuyến trên website và giải ngân về thẻ ATM, chỉ cần có CMND là vay được. cần vay ib mình tư vấn nhé
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: Mập bụng mặc có lố k c. Áo phê đẹp mà e sợ thấy bụng
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Da đen cháy nắng qua bên mình tắm trắng là thay đc lớp da mới mịn màng cho bạn luôn nhé
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: A muon het với cả thế giới rằng vú em to như cái đấu thóc...vl
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Em ơi cho chi hỏi má hóp có phương pháp làm đuộc o em
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Ảo Plus+ ad e hỏi nhỏ.ad cx chưa có ny giống e và những người xem đúng ko ạ
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Đang chán có ai muốn chat sex không tình nguyện ạ >:(3:)<3 1550802704138
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Ghét vãi lồn thằng Nguyễn Trần Trung Quân nhái sếp sơn tùng
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('hate_speech',)
# Sequence: Khó Đoán Đời kkk em nói r thôi em năm ni chưa trúng
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: dạ,hôm nay hoặc ngày mai sẽ có nhân viên bên shop goi, tư vấn và xác nhận đơn hàng, chị thấy số lạ vui lòng bắt máy giúp em ạ!
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Co xx 65Kg lung de minh nhe minh tang do ma
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Ngân Annh cậu cứ nói bừa tại lớp mình chịu khó nhặt cỏ hơn lớp cậu đó
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Vay vốn giải ngân ngay trong ngày, chỉ cần cmndChấp nhận nợ xấuTham khảo link dưới nhé1-4tr 0% lãi xuất 10 ngàyLink: https://shorten.asia/BCtbVKfBAvay chỉ cần sim viettel chính chủ vay tới 70trLink: https://shorten.asia/dgKtC9a9Tima app duyệt tự độngLink : https://shorten.asia/jq6Hja5w
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: Kiềuu Trâm Trinh Ngô Nqọc Bích Bùi Thắm Hồ Hiền Giao Trần Giao, triển k mấy e
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Hồng Loan kh qt cho lắm... Lại bảo mình nhãm
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Thảo Ly t đã ngu rồi m còn ngu hơn t à
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('harassment',)
# Sequence: Video full HD EM thần dâm cháu gái danh hài CHiến thắng gợi cảm xin mời anh em Xem thì vào ----> Phim 18+
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Quang Huy vã thật cậu ạ. 1 năm nay mạng nhện bâu đầy bẹn nè
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Vâng, cho e hỏi nhấn mí dc bao nhiêu lâu ạ. Có dc Vĩnh viễn ko
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Hoàng Văn Uốn cố gắng nhé thế con thì ở với ai e
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Thùy Linh Trần Nguyễn coi con trai của đạo diễn Trần Khải Ca đi
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Hảo í hí hí hí hí m hiểu roài sao??! Ôi dồi xem phim phải nói thính tát vào mặt t :)))
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Nguyễn Thảo Nguyên thôi hokk có mập chọc hơi khóc nữa
# Predicted label: ('harassment',)
# Hand-labeled: ('harassment',)
# Sequence: dạ chị dùng máy này massa giúp săn chắc ngực hơn ạ
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: vay nhanh không cần thế chấp chỉ cần CMT, có số điện thoại https://shorten.asia/KBj8ecgt
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: Ban o dau co giao hag o bih duong k bn
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Nguyễn Hoài Bảo m hơn được ai mà lắm mồm thế :))
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('hate_speech',)
# Sequence: Chào bạn, đôi bạn chọn set áo phao đôi nào ạ, bạn ib mình tư vấn kỹ hơn cho 2 bạn nha _^
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Pham Sy Đăng ký hồ sơ trực tuyến trên website và giải ngân về thẻ ATM, chỉ cần có CMND là vay được. cần vay ib mình tư vấn nhé
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: Haizz đã bảo tin tuyển dụng mờ không phải a viết mờ
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Sao mũi bên Trung perfect thế nhỉ? Nam nữ đều cao :((
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Hồi Hòa vậy thì chúc ng đẹp ngủ ngon nha
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Đang hứng tình ai inbox show hình luôn :/>:(:O1550807337614
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Bắn bỏ ngay thằng việt gian phản động làm gương cho kẻ khác. Linh mục với mịch gì nó là nguyễn ánh định cõng dắn gà nhà lần nữa đó
# Predicted label: ('harassment',)
# Hand-labeled: ('harassment',)
# Sequence: Lúc Công an còng cổ, thì khóc lóc, địt mẹ bọn bú lồn Trung Quốc
# Predicted label: ('hate_speech',)
# Hand-labeled: ('harassment', 'hate_speech')
# Sequence: Dạ em chào anh ạ. Mẫu này giá quảng cáo là 1tr5 anh ạ, khách cũ đã Like page bên em sẽ đc giảm còn 1tr2 ạ
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Minh chi can đem do đen la dc dung ko ad. Con Tiên thi tinh sao a. E ko hiu cach theo doi Tiên minh ban dc
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Phun môi cấy tế bào gốc phủ bóng Collagen giá 6 triệu khi em chia sẻ bài viết chỉ còn 1.700.000đ, Khi em tới với Mailisa em sẽ được đội ngũ chuyên viên tay nghề giỏi tư vấn chọn màu, vẽ dáng mẫu đẹp, trọn gói tạo dáng môi cười, xử lý môi thâm, phun môi đẹp tự nhiên. Bao đẹp 100/100, cấp phiếu bảo hành đẹp cho từng khách hàng.Tổng thời gian làm khoảng 1 tiếng, thiết kế tạo dáng, ủ tê, phun, pha phối màu, cam kết hoàn toàn không đau, không sưng, không chích tê, không cần nghỉ dưỡng, không cần ăn kiêng, dụng cụ mới vô trùng riêng biệt, khi mới phun xong màu hơi đậm 1 tí, thông thường từ 3-5 ngày sẽ có lớp mài bong tróc, lúc này em đã có 1 bờ môi đẹp, tuy nhiên để màu lên chính xác từ 2-3 tháng màu sẽ ổn định lên đều và đẹp tự nhiên. Nếu lúc đó em cảm thấy thiếu sót vài mũi kim, vui lòng quay lại nhà Mailisa dặm tuốt tát cho đẹp long lanh em nhé. Khách nhà Mailisa đông như trẩy hội, nhưng em yên tâm
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Tôm Tít cho t xin chiều cao cân nặng t tư vấn sz b nhé
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Nếu mi ít yếu thì nên nối tự nhiên thôi,không nên làm dày
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Mỹ phẩm Nhật - Zô shop Kể cả da ngăm cũng không kén ạ chị?? :3
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Thu Uyên hay là ny m còn đang đi học ngày đầu tiên :>
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Đặng Thái Đạt cưới đi để ae tập trung bựa Hoàng Thái Nguyên hè
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Cái mõm mày gần tai mày.mày chửi mày nghe nhé con chó ghẻ già
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('harassment', 'hate_speech')
# Sequence: Muốn giàu mà k phải làm đợi giàu từ trên trời rơi xuống thì ra ngoài trời đặt cái chai giữa trời. Khi nào con chim nó ỉa đúng vào giữa cái chai thì lúc đấy đi mua vé số đi sẽ trúng đấy. Địt mẹ muốn ăn mà k muốn làm thì chỉ có bốc cứt à ăn thôi. Đéo có cứt mà bốc luôn chứ ở đấy mà ập đến. Chẳng có cái đéo gì tự dưng mà đến cả. Phải lao động và hy sinh hết
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Helen Natali xem đi để ko tiếc nữa :)) những cái khác tốt hơn đang chờ :))))
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Nguyễn Đình Khánh Tường t còn! Thế 2 vk ck ở bd luôn ak???
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: A ơi bô Âu Á hộp này mà dục mặt bàn thuận buồm xuôi gió thì giá bao nhiêu ạ
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: I used to get the smart ass comment about not paying for a seat. Why have any then? People aren't safe having to stand.
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Nguyễn NhưÝ Nhi là Nhi hỏng có mê trai nhe Ý :v
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Chuyển tiền từ tk sang tk khác ko cần ra cây thê nào đấy ak
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Tội Chiến caChúc mừng sinh nhật mà em nó còn chả thèm để ý tới@@
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Phạm TuấnAnh Mà thấy hôm nọ em lào gọi "Anh Yêu "Đéo sượt ngày lào cơ mừ :))
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Đàm Việt Hùng Thieu Quang Lynh Phương có chỗ đi chơi r
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Đức Manh đồ sơn phang như thật còn bày đặt trinh là j vậy
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Nguyễn Thu Phương Thắm Nguyễn Bích Phương Phương Sting Dâu Hương Ken Trà Hương Trà Mi Tô Thùy Dung Thư Nguyễn Huyên Trần Đỗ Hằng Lê Lý Like hộ e với ạ
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Vừa nghe nhạc, vừa nhìn vếu còn gì tuyệt bằng
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Đặng Thế Anh trời ơi vk kg triệt cx kg đến mức v đâu ck ạ@@
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Có ảnh hưởng của dòng máu lạc hồng iron bird đó nha Lê Anh Tuấn thank you chíu chíu nhá
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Bạn bị mụn ẩn lâu chưa và tình trạng da hiện nay thế nào ạ?
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Xuân Quỳnh xem ảnh từ nhỏ của Bác là mũi, cằm đều hoàn toàn giống hiện tại. Không biết ngu thiệt hay giả ngu mà bảo sửa
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('harassment',)
# Sequence: Khổ tâm quá, cứ thấy trai đẹp đẽ, trắng trẻo, cao to hoài lun... ghét cẩu lương thật sự
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Chu Hải Anh à. Chết nha. Mình ko được biết.
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Tuấn H-ồng K-ông An Kòii chỉ sờ đít con ng ta thôi
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Shinhanbank hỗ trợ khoản vay theo lươngVay theo bảo hiểm nhân thọ khoản vay lên tới 500 triệu lãi suất từ 0,8%thủ tục đơn giản bảo mật thông tingiải ngân nhanh chóng sau 24h. https://shorten.asia/qY6kUTqSLink đăng kí mở thẻ tín dụng shinhanbank https://shorten.asia/qY6kUTqS
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: Cái cmm, ko chống tàu sao có sự kiện 17/2/1979? Ngu vừa thôi kẻo ngu hết phần của chó nhé. Nhìn quân đội cộng sản đánh với tàu như vậy có thấy hổ thẹn ko khi lũ 3 que xỏ lá chạy chít chết?
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('harassment',)
# Sequence: Tuan Jony nếu b k thông cảm dc thì cũng đừng phát ngôn kiểu v. B chỉ được nghe chưa dc thấy. B cũng chưa tiếp xúc với họ. Chưa sống hết đời chưa biết ai khôn ai dại đâu b ạ
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Góc tâm sự. Mình đang là mẹ bỉm sữa. Ở nhà thì không có tiền. Đi làm công ty thì cũng không được. Bán hàng ol thì không xong. Mới đây e vừa biết một công việc làm ở nhà, Công việc copy và dán link. không bán hàng cũng ko đi lại tháng kiếm 5-7tr nhẹ nhàng. Em đã học qua khóa học online và Tháng đầu tiên e đã kiếm dk 7tr rồi. Ở đây mẹ nào bỉm sữa như e muốn tìm việc ở nhà tháng kiếm 3-5tr thì ib e hướng dẫn cách cho mà kiếm tiền. Tham khảo Facebook của mình để hiểu rõ nha.
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Em muốn biết nếu cơ địa ko có mỡ thừa để hút và cấy thì đặt túi thông thường có đc tự nhiên ko. Vì mông em bị hóp hai bên hông, em muốn làm mông lâu r nhưng lo ngại túi đặt mông ko đc tự nhiên/
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Selina Evan thấy bụg mấy ngấn là có rồi đó haha
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('harassment',)
# Sequence: Đông Hoàng bạn vui lòng truy cập page Tuyển Dụng của F88 để xem thông tin tuyển dụng của F88 nhé.
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Mih muốn mua goi liệu trinh tam, vay mỗi lần tắm cách nhau bao nhieu ngay
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Có cỡ 25 cho bé 4 tuổi hơn gần 5 tuổi không bạn
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Sức khoẻ cái l.. Vợ say no là ko đc hút
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Người VN k nói ngược c njes. Nói dễ nghe tí đi chị. CHỐT LỒN CHỐT LẮM hj
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Chỗ gần hào nam giảng võ ýM la liếm cmt xem=)))
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('normal',)
# Sequence: Suy nghĩ từ đầu h chiều đến tối vẫn kB ăn z.....
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Cho e xin địa chỉ e mang cái đệm nhỏ qua ạ
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Nguyễn Thị Nga a lại k quan tâm e nga r
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Nhớ cho t ăn vs nha! T cũng chơi mà k đk! T ghét m rồi H ợ! Mà đã nhổ đk răng chưa mày?
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Sấp mặt lồn ra đấy lại đổ tại sốbố mẹ ở nhà thì vẫn “ cháu nó ở nhà ngoan nắm “..
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Pic 1: Trạm khi ở núi Bách Phượng (nhìn baby vậy thôi, cởi áo ra mới thấy chi tiết ở tập 5, chi tiết sâu sâu nữa thì hỏi Nguỵ Anh )Pic 2: Trạm sau khi Tiện sống lại
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Tuấn Ninh nhiều thế này thổi bjo mới hết
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: DTJ Chào bạn! bạn vui lòng inbox cho shop để được tư vấn và hướng dẫn đặt hàng. Hoạc truy cập website http://trangsucdtj.vn/nhan-doi-bac
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Đoán xem con này được bao nhiêu tuổi mà dễ thương vậy
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Anh có gặp khó khăn cho việc được cấp bằng sáng chế không.
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Bạn vào đường link phía đưới để được tư vấn rõ hơn nhé
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: "người bí ẩn cô gái đầy nghị lực chị chúc em Sn vui vẻ luôn trẻ khỏe đẹp
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Giống iclould quá vậy hihi. Dme nói thật hack là bị hack mk 100 ký tự cũng chết
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('hate_speech',)
# Sequence: Trần. T. T. Hường chắc gì ngủ đã nằm mơ thấy anh@@
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Hanh Nguyên tranh thủ chộp hình lúc còn đẹp thôi
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Đm việt nam thiếu gì cái hay mà cứ đăng của bọn trung cộng!
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('hate_speech',)
# Sequence: My ơi báo đơn dùm chị để chị CK,mai thứ 7 ko chuyển đc nha em
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Phải xương nhà minh canh công an thành phố không nhi?
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Nguyễn Phương Thảo Bé này béo gấp đôi gấp 3 Xù gấp 4-5 lần Gấu ý.
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Nguyễn Trâm no e k thích cong hay thụ đâu trai thẳng nha
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: đm thằng đi xe máy đã yếu còn tỏ vẻ, ông ô tô nhịn k muốn đấm chứ thằng này cái đấm thì thiếu cái đá thì thừa
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('hate_speech',)
# Sequence: chị thích brand này lắm. sang trọng, chất lượng. đặc biệt các chai mini để đi du lịch là càng thích!
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Câu 2 em nghĩ là văn học phải có chức năng phê phán hiện thực nhưng bằng trái tim ấm nóng của ng nghệ sĩ,hiện thực phản ánh trong tác phẩm phải chứa đựng tình cảm, tư tưởng lớn. Nhà văn-nhà thơ không phản ánh hiện thực một cách chủ quan cũng ko phải là người sao chép hiện thực, hay “tên hề lóc cóc chạy theo đuôi đời sống.
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Cái này thì hơi chơi khó nhau. Kiểm tra vào đúng ngày rằm thì anh nào đen a đó chịu. Chứ 90% là về hết.
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Nguyenhiep Nguyen :)) ngu như m đòi ỉa nhà ai debate k đc mẹ vs con lmjNói chung n đéo đủ đẳng cấp nhóc ác :)
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('harassment', 'hate_speech')
# Sequence: Nguyễn Hồng Thúy em bơm mông vs zú hông?? Free nha.
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: BẠN CÓ NHU CẦU MỞ THẺ TÍN DỤNG THAM KHẢO VÀ ĐKI CÁC NGÂN HÀNG DƯỚI ĐÂY K MẤT PHÍ MỞ THẺ, DUYỆT HỒ SƠ NHANH CHÓNG, AN TOÀN1Citibank: lương ck từ 8trieu nhận lương qua,có hợp đồng lao động, trên 21t, hỗ trợ khu vực HN, HCM.Dki tai đây https://shorten.asia/qPaatRFa2VPBank : dành cho kh nhận lương qua tk từ 4.5trieu,là khách hàng nhận lương qua tk hoặc kh sử dụng mobiphone được duyệt trước, áp dụng cho Kh từ 25-40 tuổi. Khu vực HN & TPHCMhttps://shorten.asia/n3KTxwum3Shinhanbank : mở thẻ tín dụng dành cho kh có lương ck từ 7,1trieu, có HĐlĐ từ 12 tháng, dành cho kh ở Hà Nội và HCM, Việt nam.Dki tai đây https://shorten.asia/58nr@@
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: Cô chụp hình nhiều nhiều cho tụi con xem vs nha cô
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Nguyễn Thị Phương Uyên k biết làm sao hết :((((( bữa nói ctua u mê Chiến quá bữa nay nghiệp quật
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Tống Gia Bảo lồn mẹ M lâu ngày ko chọc t chửi buồn phải hoing dung chọc t ak
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Thaohadung Le 2cai dú cua ba no chay sẽ xuog tuot duoi hán...de danh cho thag nhảy ranh hy mui chua sạch kia..co lở nằm phía sau lưng ba ma them bú đúng...ba chi can nam cai dú bả liệm ra đằng sau la thag hc kia chụp lấy bú lien
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Bác Hồ của chúng mày là con súc vật, chúng tao gọi là Hồ Bá Chó ăn ở trong hang pắc bó, mày có biết kg, hỡi lũ ngu đần dốt nát, óc chúng mày chưa lớn nỗi, Hồ Bá Chó là thằng dâm tặc đã hiếp biết bao nhiêu phụ nữ, khi có con kg dám nhận là con của mình, đúng là thằng sở Khanh, dám làm mà kg dám nhận. Phúc cho chúng mày có thằng Bác kính yêu lại là thằng sở khanh, khốn nạn nhất trên đời.
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('harassment', 'hate_speech')
# Sequence: chuyện gì xảy ra sau khi cô bé đó bỏ khẩu trang :D
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Mộc Quế Anh đây đây! hậu trường cảnh hot nhất tập rồi nè@@
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Bích Ngọc em nên chọn oppa hay soái ca đây
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Trang's Cún'n sắp rồi e ơi cứ ngồi yên ty khác đến thôi ngủ đi a ngủ đây mai đi lam
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Hoàng Thắng đừng coi thường ng da màu Gầy nữa chấm hết
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Trần Thu Mai bạn m nhắm mắt. Đ thấy gì cả.Đm. Nhiều chồng vđ.
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Tinh cha me dam sau voi con o bo benMot doi chat chiu nuoi con o ngai nhoc nhanCa tinh thiong dat len tuong lai cho conHay truong thanh y thuc cach cu xu de cha me vui longLay hieu kinh nghia thao dap an tinh cha meBan luon lam viec ich du nho nho ma am long song thanChuc ban voi cha me luon la con ngoan cuoc song ban moi viec se deu tot dep
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Sao ko mướn sát thủ ám sát thằng đầu não cho đi
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: Nếu e muốn cấy mỡ ngực mà tập gym thì có ảnh hưởng gì đến ngực k ạ
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Nguyễn Quân mẹ mày đẻ ra mày chắc đau lồn lắm nhỉ...bữa t địt cho đã toang hết ra rồi. Lại phải đẻ ra loại súc sinh như mày
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('harassment', 'hate_speech')
# Sequence: <3 NGƯỜI THẬT VIỆC THẬT, NÓI ĐI ĐÔI VỚI LÀM chính khách hàng mới là người đánh giá rõ nhất về chất lượng dịch vụ, hình ảnh khách hàng thực tế sử dụng dịch vụ làm đẹp tại Mailisa, làm xong ưng ý hài lòng đã gửi tặng tag qua Mai Lisa rất nhiều hình ảnh, em nhe!
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Chớp mắt đã vạn năm vs Bồ đề kệ nhé b
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Hôm qua tui ngủ nằm mơ thấy có phim r đang coi thì bị kiêu dậy khọc 100000 lần thứ tiếng luon akkk
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Chẳng qua đứa đó k có ny mới k đòi quà thôi. Điển hình như t
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Đinh Trung Hiếu kìa cô gái. Cho hiếu úp mẹt vào mông cái đi
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Vayvnd hỗ trọ vay 1-3tr lần đầu, lần sau vay được đến 10tr. Miễn lãi 10 ngày đầu tiên. Đăng kí tại đây: https://rutgon.me/mooD4d
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: Trạc https://shorten.asia/cfq7HUtAẤn bào link này để khám thảo và đăng ký nha
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: Sống phải giữ lấy cái đức, để cho con cháu đời sau nó hưởng. Đấy là mấy bạn cmt vậy chứ mình là mình tố cáo chết cmnl ý chứ, ngu còn thích thể hiện. hihihi
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('harassment',)
# Sequence: Meo Hoang Miền Nam cũng đầy đứa ăn nói kiểu đấy, kiểu như " đụ má "
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('hate_speech',)
# Sequence: Địt mẹ mấy e nhỏ còn nhát ấy mà chờ đánh banh xog đi r nhộn nhịp drama hít đéo đều
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Dm thằng lôn mày nghèo chắc mày ko có vk hả
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Học thì ngu cứ tối ngày never dieeeee Diee diee cái địt mẹ chúng mày
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('hate_speech',)
# Sequence: Vân Yêu giờ nhà t chỉ có 1 đứa mập thui nên chắc ko đc vậy rùi
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Chào em, yêu cầu tối thiểu là tốt nghiệp cấp 3 em nhé
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Pham Pham mắc mẹ gì hong được. Có luật cấm không cho biến về để lính ăn trụ à? Hay thua cay quá nên vào đây sủa dơ
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: ngân hàng Shinhanbankhttps://shorten.asia/VxN97btqngân hàng MB bankhttps://shorten.asia/1gTgPgT4Ngân Hàng Sacombank, vay tiền online chưa bao giờ dễ đến thếVay trực tuyến không phải tới ngân hàngSố tiền lên đến 200 triệu đồng trong 12 tháng Lãi suất ưu đãi, chỉ phải trả lãi theo số tiền và thời gian sử dụng thực tếchỉ cần 3 bước đơn giản, có ngay tiền về tài khoản! Ace cần đăng kí tại đây nhémở thẻ sacombankhttps://shorten.asia/rx92TGGE
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: Ha Lulu thế mai đổi sang sờ mát gạch thôi nhể
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: TẬP NHỮNG NGÂN HÀNG CHO VAY TÍN CHẤP UY TÍN GIẢI NGÂN NHANH https://sites.google.com/view/vay-tin-tr-gp/trang-ch%E1%BB%A7
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: Chào bạn, bạn vui lòng check inbox giúp mình nhé! Cảm ơn bạn nhiều!
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Con cám ơn Cha.câu chuyện thật cảm động và rất ý nghĩa.
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Hoànn Xuân Nguyễn fan Việt Nam cái đầu buồi nhà m. Éo biết m theo dõi vn dc bao lâu, chơi lq được mấy mùa. Fan phong trào thì nói mẹ m đi. Lúc fl chưa vô địch dtdv lúc đó chắc m đang bú cc ở xó nào r. Dân Vn éo ai cần loại fan sv dân trí thua súc sinh như m. Những thành phần như m chỉ làm ô uế đất nước chứ éo có cc gì tự hào
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('harassment', 'hate_speech')
# Sequence: Xuxu Nguyễn tui k thích ăn cẩu lương mệ êi
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Chào bạn, sản phẩm có giá 280 k/ bánh sử dụng được trong 2 tháng bạn nhé!
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Canh Thân hỳ...muốn quất lắm a ạ...nhưng ốm dài đây này a ơi...
# Predicted label: ('normal',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: nó trên núi đéo bít con cặc gì mà khoái sủa ák.
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('hate_speech',)
# Sequence: Đợi nó có đi rồi địt mẹ mày đéo là cl gì đâu nhê :)))
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Đã được học nhưng chưa thực hiện đọc lt thì dễ nhưng để th được thì đó là cả 1 quá trình.
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Cho em hỏi tóc thưa mk cắt ntn thì hợp ạ
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Ngan hàng quan đọi MB bankMỏ tài khoản MIỄN PHÍCho vay trả góp 12-36 thángVay được 10-100 Triẹu, KHÔNG PHÍ TRƯỚCChỉ cần có CMND Dòng máy Android đky tại đay:https://shorten.asia/ZD5cPV1tMáy IOS đky tại đayhttps://shorten.asia/egV4jrvG
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: Will they be over crowded like your 3.16pm service from Southern Cross? Packed like sardines but told to keep moving to let more people on. DISGRACEFUL Vline!
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Em khuyên anh đừng chụp với vợ mình nhiều quá vì anh bị dìm đấy@@
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Các đơn vị, tổ chức vay tiền tốt nhất tại đây: 1. Cashwagon vay tiền mặt trực tuyến. Đăng ký để tỷ lệ duyệt hồ sơ được 1-10tr https://shorten.asia/XvwHTp5g2. AVAY: Vay online nhanh chóng từ 1-70 triệu, duyệt hồ sơ tự động. https://shorten.asia/wR7t62mE3.Vay vĐồng, chỉ cần CMTND, không thế chấp.https://shorten.asia/9k9thV7Y4.TIMA: vay online, duyệt qua điện thoại. Điều kiện linh hoạt.https://shorten.asia/59cMPheM5.Robocash vay nhanh, giải ngân trong ngày.https://shorten.asia/bvm86n1K6.Vay tín chấp Shinhan Finance. Vay từ 10- 100 triệu, giải ngân khoảng 2-3 ngày, lãi suất chỉ từ 0,8-1,8%/ tháng.https://shorten.asia/95qUY7xz7.CreditNow: Nền tảng công nghệ
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: Dung Khôi thân mến! bạn vui lòng cho mình biết bạn bị thâm vùng môi lâu chưa. với tình trạng bị thâm môi bên mình khắc phục được cho bạn nhé và sẽ phun xăm màu môi được như bạn mong muốn nhé. bạn vui lòng inbox hoặc để lại số điện thoại chuyên viên bên mình sẽ tư vấn chi tiết hơn cho bạn nhé
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Ôi cái da mặt nàng! Có biết là niềm mơ ước của tui hem? Chia sẻ đê
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Ta đâu có ác chỉ là hoàng cảnh bắt ác mà thui
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Chào bạn Nguyen Thuong! Bạn check inbox mình tư vấn nhé
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Hồ như dit tổ mày.rôi gia đinh may cug vay thoi.đeo co ti tinh nguoi.con cho
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Phạm Thái Hoàng Long ồ loại m đ cãi dc là lại địt mẹ mày à, loạn luân vcl
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Cảm ơn b đã quan tâm đến dịch vụ tại spa.B vui lòng để lại sđt hoặc check ib để spa tư vấn cẩn thận hơn cho b nhé.
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Lê Khắc Tuấn địt mẹ. Ăn với đi du lịch chụp ảnh các kiểu mà
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Nguyễn Nam bộ cl bố m k muốn đi tù
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Địt mẹ làm lồn cần like cmt ib gửi link, địt mẹ cho anh em xem luôn cho nóng, http://bfy.tw/LOr7?fbclid=IwAR1GTNSaeejijyIDoChMQLrT--8WVLWvctAkNAXvGls29nVM0Avk_SMAO8sLike cho tôi phát
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('hate_speech',)
# Sequence: Nguyễn Duy Khánh ăn cái máu lol j mà vú vê khiếp nhể
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Đắng Cay Cuộc Đời bạn ns thế chịu bạn gặp trực tiếp ngta mà lm vc ngu cứ tỏ ra khôn lz. Ai ns nợ xấu ko vay đc bạn ko quen biết ai trong ngân hàng vào vay ai chả ko hỗ trợ. Quan hệ ko có, có những ng quan hệ tốt họ lo đc
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('hate_speech',)
# Sequence: Mỗi ngày đều có cẩu lương đập vào mặt thật thoải mái ô
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Biết sao giờ,Lam Trạm đã nói rồi : đạo này hại thân,hại cả tâm tính
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: T biết sight nhưng t thích viết side vì nó quen tay
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Qua cả 2 chứ qua Trung tìm các tiểu ca ca rồi qua Hàn tìm oppa=)))
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Minh Thu Bạn chủ động nhắn tin để nhân viên tư vấn miễn phí!
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: My Linh cc đi đâu cũng kêu ny mk dcmm
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Chào bạn, set váy áo bạn đang quan tâm, shop mình vừa về hàng bạn nha, bạn cho mình chiều cao cân nặng nhé, mình tư vấn size vừa với 2 bạn ạ!
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Yến Yến ơi! Mộc An đã nhắn tin cho bạn, bạn vui lòng check trong Tin nhắn nhé!
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: %^ My Finance App Hotrọ vay vón nhanh nhát trong ngày Khong tón thòi gian Mọi nguòi càn vay nhanh vay gáp thì tải app vè đang ký vay nhé Thủ tục nhanh và gọn đon giản Đay là link app :https://shorten.asia/u3PjSNK8
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: ng ta có vếu ngon, ng ta hiếp dâm thị giác, + nhạc hay, lại phiêu quá ấy chứ, đúg đờn bà sân si quá cơ
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Đm thằng lìn ad a đụ đéo gì mất nết. Làm tao tưởng con ah Vua
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Vậy mà để cho nhiều vô rồi kiêu khổ ko tiền để một đứa thôi chứ.do mình hết đừng có Nho vả ai cả ba mẹ làm khổ con thơ thôi
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: chỉ la lời bien mjh.ket cục thi ng kia van dau
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Vũ Thủy cảm động thật bạn hé bạn, nhưng vẫn còn gây ro lắm vì mẹ chồng muốn chia cắt
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Yến Nguyễn kkk.giờ có miên nhay hơn e nữa gấu
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Chưa lấy chồng khúc nao ra khúc đấy,đẻ con xong chả biết ngực đi đâu hết,gìơ lại một nách hai con, bao gìơ mới thực hiện được ước mơ này nhỉ,
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: bố m thách đấu đây chưa giám càm con đó đi rừng nữa chúng m bú đít chết mẹ hết đi
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('harassment', 'hate_speech')
# Sequence: Vũ Nguyễn m sai r m loại 4 là ctm sẽ có ny cmt dạo sẽ có ny
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Bn vậy?? Mua 1 tặng 1 à??hiệu qua k?,trắng đc k
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Lam Nguyen bạn vào link đky khoản vay nha chỗ nào k hiểu ib mình hướng dẫn ạ
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: Thủ tục đơn giảnNgân hàng cho vay uy tínNhân vien tư vấn nhiệt tìnhClick vay ngay tại https://dangkyvay.com/ctv161
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: Cho e hỏi ngực thâm từ nhỏ vậy có hồng đc k ạ
# Predicted label: ('normal',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Vu Thanh Dat ý là cảm giác khi phê cần ấy.. đm ngu z@@
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Anh Tú Airtac v thì đừng nói trước, đời lắm chữ ngờ lắm nha bạn Tú thân y,@@
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Dạ b cho shop dt, địa chỉ và tên để shop gửi hàng cho b nhé
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: đứa trẻ mãi thì làm sao mà biết được cái lồn nó như nào,tao k ước
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Đào Thu Nguyệt Chào chị, chị vui lòng kiểm tra tin nhắn để được tư vấn thêm ạTHẨM MỸ HƯƠNG MI HÀ NỘI: số 6 ngõ 110 Trần Duy Hưng - Quận Cầu Giấy.Hotline: 098 505 3333 - 0921 29 29 29TP HCM: 120B Huỳnh Văn Bánh, P12, Quận Phú Nhuận.Hotline: 092 505 3333 - 0921 28 28 28https://www.facebook.com/huongnatural
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Có chưa cho chị bộ này em Huyền saze XXL 0787692931
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Nguyễn Quốc Lương bác theo rõi trang hôm nào về em đăng
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: App đoctođông hỗ trợ khoản vay từ 1 đến 10tr chỉ cần CMND và thẻ ATM http://tinyurl.com/t8pajt6
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: Ai cũng kêu ngu trong khi bản thân đã từng ngu rồi =)))
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('harassment',)
# Sequence: Ngọc Trâm đúng đúng, thầy mà đóng thể loại bá đạo lạnh lùng thì ce hk đủ trứng để rụng luôn í
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Thương Thị Đậu cị cũng chả có j ngoài mỡ nek e
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Cục sì lầu ông bê lắc địt nhau là không đi lắc
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: chào bạn! cám ơn bạn đã quan tâm tới dịch vụ tại TMV Daisy! bạn lưu ý điện thoại chuyên viên liên hệ tư vấn với bạn sớm nhất!
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Ko những dẹo mà cái mồm còn bị tật. Clm nó tao đá phát văng lên cây ổi giờ
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('hate_speech',)
# Sequence: Phuong Van Truong vớ vẩn. Đang no lm ăn nhà bao việc thời gian đâu mà nghĩ vớ vẩn
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Em chào chị, cám ơn chị đã quan tâm đến dịch vụ tại thẩm mỹ NỤ TRẦN, chị vui lòng kiểm tra inbox hoặc để lại SĐT chuyên viên sẽ liên hệ tư vấn và đăng kí KHUYẾN MÃI sớm nhất cho chị nhé Chị cần gấp có thể liên hệ hotline : 0352952828
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: <3 NGƯỜI THẬT VIỆC THẬT, NÓI ĐI ĐÔI VỚI LÀM chính khách hàng mới là người đánh giá rõ nhất về chất lượng dịch vụ, hình ảnh khách hàng thực tế sử dụng dịch vụ làm đẹp tại Mailisa, làm xong ưng ý hài lòng đã gửi tặng tag qua Mai Lisa rất nhiều hình ảnh, em nhe!
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Nguyễn Uyên mày mập kệ mày chớ tao có nói chi đâu:))
# Predicted label: ('harassment', 'normal')
# Hand-labeled: ('harassment',)
# Sequence: La verdad es que sois unos cachondos de cuidado....la ultima que que apreto caicedo fue para ir al lavabo o pedir irse en agosto.....cachondos.
# Predicted label: ('normal',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Học thì ngu cứ tối ngày never dieeeee Diee diee cái địt mẹ chúng mày
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('hate_speech',)
# Sequence: Sao c k noi dang buồn shop My tang cai xã xui chu
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Thiên Sứ vậy qua The Gangs bên Cao Thắng ăn kìa chị, rộng rãi, ngon, k mắc
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Trọng's Oppa's bố trẻ m còn dzai hơn th bố ông nội nhà m địt mẹ th quê, CÂM và CÚT
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Platypus The Perry câu phát biểu của bạn thì khôn quá ạ Bạn nói thua do một cá nhân thì bạn chả biết cái con cak gì về liên quân cả Cmt mang não đi dùm
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('harassment', 'hate_speech')
# Sequence: Dạ áo này chỉ có 1 size dưới 65kg vừa ạ
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Nhiễm Phèn lồn con này chắc như đuôi chuột ngoáy hộp mỡ nhìn kinh dị vkl mà cũng cưới
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('harassment',)
# Sequence: Hồ Hữu Hiệp thôi em. Xinh nhưng nge tiếng rên a tắt mẹ nứng. Y như lợn chọc tiế. t :@@
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Dao Nguyen địt mẹ chị e bé tuổi mà nhìn chị bình luận như đầu lồn phân biệt lồn bà chị à
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Chu Quang Nguyên đánh cho bê lồn chạy quanh nn ^
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('hate_speech',)
# Sequence: Ai chat sex với em không tình nguyện luôn ạ :'(o.O:P<3 1550807475189
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Chào hai bạn, các bạn chọn set đồ đôi nào ạ, bên mình có đủ size cho các mẫu bạn nhé, bạn chọn mẫu shop tư vấn và báo giá giúp bạn nha ^
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: nó lại bị chuẩn ấy. Đi thi trắc nghiệm auto đen :v
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Pé Thơ móa sad cực mạnh :(( thôi tau lên youtube ngắm ổng cho đỡ nhớ ><
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Duma. Chứ đéo phải h m chơi les t hả. Kkkk
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Mi Ha Vu toàn mấy e ng như cái sào í
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('harassment',)
# Sequence: Dăm ba con chó tín dụng đen tụi m dám tới nhà ai? Láo lol quen. Ngu thì chết. Toàn bọn tàu khựa đòi đe dọa dân VN à? Tuổi cc
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('hate_speech',)
# Sequence: Dùng đầy... đi công tác, đi chơi hay là về quê các kiểu nói chung đi xa ai mà chả từng kẻ nhà nghỉ hay khách sạnVà đương nhiên rồi... đi với gái@@
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: V LIVE v là ai đến trước sẽ được vào trước thảm đỏ hay có phân chia khu vực VIP vs Ga
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: S la z lam s dti dep hon ldp dk. K thic
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: C nhàn ơi còn ko ạ? Ship luôn cho e đk ko
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Chú nó cho ịt là may rồi còn phân biệt vùng miền.@@
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: Bichlinh Nguyen sao lại tag em dọ. Vì em ko coá chửi bậy. Ahihi đồ ngok
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Đm lẩu mới chả nấm muru, cho tiền, dải thảm đỏ cũng méo đến lần 2 nhéMỹ Hạnh Đinh
# Predicted label: ('hate_speech',)
# Hand-labeled: ('hate_speech',)
# Sequence: Tịnh Nhi kaka e ngủ sớm đi cho da nó đẹp
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Trên phim anh chiến hữu ng ta ghê lắm mà Dương caca
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Hoàng Hữu Bích t vẫn gọp mặt đầy đủ trg hội mê troai há há
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Dương Văn Thành như cái pha băng vào cuối trận của thằng elly kiểu có bất tử ma thân ấy gọi là xử lý ổn ah. Thua thì là cả team nhé. Đừng lôi 1 cá nhân ra làm gì
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Nguyễn Minh Thiện Dương Thuý Vy dô thấy cmt cái tao suy nghĩ liền r minh thiện có cái dì để dụ@@
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Sẹo của mình là sẹo lỏm do mụn để lại, sẹo mình cũng lau rui, mình ở quảng Nam, nên cho mình hỏi điều trị hết sẹo lỏm ko. Và giá bn, bao nhíu lần điều trị?
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Con súc vật này ở hành tinh nào xuất hiện ra thế,mặt chẳng khác cái hậu môn chó..!
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('hate_speech',)
# Sequence: bạn Bạn Chịch =))) chúng ta quên mất những nơi này
# Predicted label: ('sexaully_explixit',)
# Hand-labeled: ('sexaully_explixit',)
# Sequence: dạ size lớn nhất là 3XL bạn nhé, bạn cho mình xin chiều cao và cân nặng mình tư vấn size cho 2 bạn ạ _^
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Phạm Hồng Châu Nhìn mặt con husky xong ko còn qan tâm đến con kia nữa, qá ngáo =))))))
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Thu Phượng quấn nhiều quá con lại nóng quá ay vk ạ
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Nguyễn Thành Nam bữa nào bắn pug nha Rip mụp ^
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Gai que choa xinh phai biết.co len vo vong Ck e oi
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Nguyễn Phan Thuận èo. Thèm trà sữa anh thuận mua qá
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Bạn ơi, Farm vừa inbox cho bạn rồi nè. Bạn check inbox nhé!
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: hôm nào lạnh chút nhá bác Diệu Hoa, bố Duy Nguyen
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Thai Linh Pham em ở 47 phố an trạch (cát linh) ah
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: si señor el español caminado con paso fuerte a 2º....por dios esto solo lo pudo hacer alguien que odie el español
# Predicted label: ('normal',)
# Hand-labeled: ('hate_speech',)
# Sequence: Chuẩn, vô tâm đi tết có lẽ sẽ vui một cách chọn vẹn. Thích ăn gì thì ăn, thích làm gì thì làm, ngủ nướng tán gẫu quây quần bên gia đình như những ngày xưa... thỏa nỗi nhớ mong ao ước vậy là hạnh phúc - là toại nguyện.
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Bắc kì cái địs con mẹ mày! Mặt mũi sáng sủa phát ngôn như con card
# Predicted label: ('harassment', 'hate_speech')
# Hand-labeled: ('hate_speech',)
# Sequence: Bạn ơi, check inbox Farm ngay nhé ^ Farm inbox bạn rồi đây :*
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Ai cũng đẹp nhưng tao vân thich triệu vy vs thư kì
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: Đồ Đôi Mẹ Và Bé, Áo Gia Đình - ANAN Shop ko pai mau vag kia
# Predicted label: ('normal',)
# Hand-labeled: ('normal',)
# Sequence: thế tự tử bằng cách uống thuốc ngủ thì sao ạ :>
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)
# Sequence: Dạ Khoản vay của Anh/chị là bao nhiêu ạ? hiện F88 cho vay theo hình thức cầm cố tài sản, nhận cầm: Ô tô, xe máy, đăng ký xe(cavet) ô tô – xe máy, điện thoại, laptop, máy tính bảng, trang sức, máy ảnhạ. Ngoài ra F88 mới triển khai thêm dịch vụ cho vay qua đồ gia dụng tại một số khu vực mà Tài sản Anh Chị sẽ vẫn được sử dụng ạ. Anh Chị có cân nhắc cầm được tài sản nào không ạ?.
# Predicted label: ('dangerous_content',)
# Hand-labeled: ('dangerous_content',)

# %%
accuracy = correct_predictions / total_samples
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.8481481481481481

# %%
# At least one of the predicted labels was true
accuracy = correct_predictions / total_samples
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.9851851851851852

# %%
# Nhập chuỗi từ bàn phím
input_text = "mày ngu quá"

# Tokenization
encoded_input = tokenizer.encode_plus(
    input_text, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    padding='max_length', 
    max_length=256, 
    truncation=True,
    return_tensors='pt'
)

input_ids = encoded_input['input_ids'].to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
attention_mask = encoded_input['attention_mask'].to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))

# Dự đoán
model.eval()
with torch.no_grad():
    outputs = model(input_ids, attention_mask=attention_mask)
    predictions = torch.sigmoid(outputs.logits)
    predicted_labels = (predictions > 0.5).int()
    predicted_labels = mlb.inverse_transform(predicted_labels)

# In chuỗi và nhãn dự đoán
print("Chuỗi bạn nhập:", input_text)
print("Nhãn dự đoán:", predicted_labels[0])
# Out:
# Chuỗi bạn nhập: mày ngu quá
# Nhãn dự đoán: ('harassment', 'hate_speech')

# %%
# Nhập chuỗi từ bàn phím
input_text = "sao mày ngu thế con đĩ"

# Tokenization
encoded_input = tokenizer.encode_plus(
    input_text, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    padding='max_length', 
    max_length=256, 
    truncation=True,
    return_tensors='pt'
)

input_ids = encoded_input['input_ids'].to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
attention_mask = encoded_input['attention_mask'].to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))

# Dự đoán
model.eval()
with torch.no_grad():
    outputs = model(input_ids, attention_mask=attention_mask)
    predictions = torch.sigmoid(outputs.logits)
    predicted_labels = (predictions > 0.5).int()
    predicted_labels = mlb.inverse_transform(predicted_labels)

# In chuỗi và nhãn dự đoán
print("Chuỗi bạn nhập:", input_text)
print("Nhãn dự đoán:", predicted_labels[0])
# Out:
# Chuỗi bạn nhập: sao mày ngu thế con đĩ
# Nhãn dự đoán: ('harassment', 'hate_speech')

# %%
# Nhập chuỗi từ bàn phím
input_text = "hiếp dâm ẩm thực"

# Tokenization
encoded_input = tokenizer.encode_plus(
    input_text, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    padding='max_length', 
    max_length=256, 
    truncation=True,
    return_tensors='pt'
)

input_ids = encoded_input['input_ids'].to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
attention_mask = encoded_input['attention_mask'].to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))

# Dự đoán
model.eval()
with torch.no_grad():
    outputs = model(input_ids, attention_mask=attention_mask)
    predictions = torch.sigmoid(outputs.logits)
    predicted_labels = (predictions > 0.5).int()
    predicted_labels = mlb.inverse_transform(predicted_labels)

# In chuỗi và nhãn dự đoán
print("Chuỗi bạn nhập:", input_text)
print("Nhãn dự đoán:", predicted_labels[0])
# Out:
# Chuỗi bạn nhập: hiếp dâm ẩm thực
# Nhãn dự đoán: ('sexaully_explixit',)
